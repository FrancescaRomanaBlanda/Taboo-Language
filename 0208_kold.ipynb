# %%
import json
import pandas as pd

# 파일 경로
path = r"C:\Users\82109\OneDrive\바탕 화면\LexicoGraphy and GenAI\Lex_Project\kold_v1.json"


with open(path, "r", encoding="utf-8") as f:
    data = json.load(f)

# 전체 구조 확인
type(data), len(data)
# Out:
# (list, 40429)

# %%
df = pd.DataFrame(data)

# %%
df.shape
# Out:
# (40429, 11)

# %%
df.head(10)
# Out:
#             guid      source        date  \
# 0  kold-v1_00000  naver_news  2021-07-25
# 1  kold-v1_00001  naver_news  2021-04-13
# 2  kold-v1_00002  naver_news  2021-09-15
# 3  kold-v1_00003  naver_news  2021-01-14
# 4  kold-v1_00004  naver_news  2021-05-06
# 5  kold-v1_00005  naver_news  2021-08-02
# 6  kold-v1_00006  naver_news  2021-04-24
# 7  kold-v1_00007  naver_news  2021-07-31
# 8  kold-v1_00008  naver_news  2021-06-03
# 9  kold-v1_00009  naver_news  2021-09-28
#
#                                         title  \
# 0                     페미니즘이 범죄가 되는 나라 [삶과 문화]
# 1                 [젠더의학①] 여성은 ‘몸집 작은 남성’이 아니다
# 2           “책 생명 늘려야죠”… 문학 속 ‘성차별’ 패치 떼는 출판계
# 3           이루다로 촉발된 젠더 논쟁... 개인정보 유출이란 본질 외면
# 4                 GS25, 브레이브걸스 포스터 또 젠더 이슈 논란
# 5           "내가 페미다" 안산 공격에 화난 여성들, 기업 불매 운동도
# 6                       “젠더 갈등? 20대들이여 속지말자!”
# 7        정치권 ‘숏컷 비방·쥴리 벽화’ 젠더 논쟁…소환되는 이준석·여가부
# 8             젠더 논란 파장…최대 패션플랫폼 무신사 조만호 대표 사퇴
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40429 entries, 0 to 40428
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   guid        40429 non-null  object
#  1   source      40429 non-null  object
#  2   date        40429 non-null  object
#  3   title       40429 non-null  object
#  4   comment     40429 non-null  object
#  5   OFF         40429 non-null  bool
#  6   TGT         20310 non-null  object
#  7   GRP         12413 non-null  object
#  8   OFF_span    40429 non-null  object
#  9   TGT_span    40429 non-null  object
#  10  raw_labels  40429 non-null  object
# dtypes: bool(1), object(10)
# memory usage: 3.1+ MB

# %%
# 랜덤으로 1개 row 보기
df.sample(1)
# Out:
#                 guid      source        date                         title  \
# 16915  kold-v1_16915  naver_news  2021-06-25  헝가리 성소수자 차별법, 이탈리아는 차별금지법 논란
#
#                       comment   OFF    TGT   GRP OFF_span TGT_span  \
# 16915  소수를 위해 다수를 역차별하는 악법입니다  True  other  None
#
#                                               raw_labels
# 16915  [{'offensiveness': True, 'annotator_id': 16915...

# %%
df.nunique(dropna=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df.nunique(dropna=False)
#
# File c:\Users\82109\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:11836, in DataFrame.nunique(self, axis, dropna)
#   11798 def nunique(self, axis: Axis = 0, dropna: bool = True) -> Series:
#   11799     """
#   11800     Count number of distinct elements in specified axis.
#   11801
#    (...)
#   11834     dtype: int64
#   11835     """
# > 11836     return self.apply(Series.nunique, axis=axis, dropna=dropna)
#
# File c:\Users\82109\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
# ...
